# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d0f73c7401a0> in <module>
# ----> 1 import streamlit as st
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5
#
# ~\Anaconda3\lib\site-packages\streamlit\__init__.py in <module>
#      74 from streamlit import source_util as _source_util
#      75 from streamlit import string_util as _string_util
# ---> 76 from streamlit.delta_generator import DeltaGenerator as _DeltaGenerator
#      77 from streamlit.report_thread import add_report_ctx as _add_report_ctx
#      78 from streamlit.report_thread import get_report_ctx as _get_report_ctx
#
# ~\Anaconda3\lib\site-packages\streamlit\delta_generator.py in <module>
#      68 # DataFrame elements come in two flavors: "Legacy" and "Arrow".
# ...

# %%
demo = pd.read_csv('demo.csv', skiprows=8, nrows=5)
industry = pd.read_csv('industry.csv', skiprows=8, nrows=20)
income = pd.read_csv('income.csv', skiprows=9, nrows=20)
education = pd.read_csv('education.csv', skiprows=8, nrows=13)

# %%
pip uninstall matplotlib
# Out:
#   File "<ipython-input-5-d6ebc6772e2d>", line 1
#     pip uninstall matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
industry
# Out:
#                                            LGA (UR)  Blacktown  \
# 0         1-digit level INDP Industry of Employment        NaN
# 1                      Arts and Recreation Services     1465.0
# 2                 Agriculture, Forestry and Fishing      667.0
# 3                                            Mining      258.0
# 4                                     Manufacturing    13070.0
# 5        Electricity, Gas, Water and Waste Services     1953.0
# 6                                      Construction    12635.0
# 7                                   Wholesale Trade     6990.0
# 8                                      Retail Trade    17453.0
# 9                   Accommodation and Food Services     8000.0
# 10                Transport, Postal and Warehousing    14215.0
# 11         Information Media and Telecommunications     3370.0
# 12                 Financial and Insurance Services    11114.0
# 13          Rental, Hiring and Real Estate Services     2237.0
# ...

# %%
education
# Out:
#                                              LGA (UR)  Blacktown  \
# 0   1-digit level HEAP Level of Highest Educationa...        NaN
# 1                           Postgraduate Degree Level    25463.0
# 2     Graduate Diploma and Graduate Certificate Level     4749.0
# 3                               Bachelor Degree Level    59472.0
# 4                  Advanced Diploma and Diploma Level    27446.0
# 5                          Certificate III & IV Level    38551.0
# 6            Secondary Education - Years 10 and above    92433.0
# 7                            Certificate I & II Level      224.0
# 8             Secondary Education - Years 9 and below    21688.0
# 9                                 Supplementary Codes    11320.0
# 10                                         Not stated    25299.0
# 11                                     Not applicable    90124.0
# 12                                              Total   396776.0
#
# ...

# %%
income
# Out:
#                                LGA (UR)  Blacktown  Blue Mountains    Camden  \
# 0   INCP Total Personal Income (weekly)        NaN             NaN       NaN
# 1                              Negative     2730.0           296.0     615.0
# 2                                     0    35116.0          4954.0    7982.0
# 3                                   149     8118.0          2329.0    2448.0
# 4                                   299    13447.0          3033.0    3354.0
# 5                                   399    20786.0          4588.0    5190.0
# 6                                   499    19448.0          5187.0    4701.0
# 7                                   649    18826.0          5154.0    5592.0
# 8                                   799    19971.0          4764.0    5748.0
# 9                                   999    25768.0          4813.0    7503.0
# 10                                 1249    30755.0          5553.0    9461.0
# ...

# %%
#define subplot layout
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(16,16))
demog = demo.iloc[:-1,:]

#add DataFrames to subplots
sns.lineplot(data=demog, x='LGA (UR)', y='Blacktown', ax=axes[0,0])
sns.lineplot(data=demog, x='LGA (UR)', y='Blue Mountains', ax=axes[0,1])
sns.lineplot(data=demog, x='LGA (UR)', y='Camden', ax=axes[0,2])
sns.lineplot(data=demog, x='LGA (UR)', y='Campbelltown (NSW)', ax=axes[1,0])
sns.lineplot(data=demog, x='LGA (UR)', y='Fairfield', ax=axes[1,1])
sns.lineplot(data=demog, x='LGA (UR)', y='Hawkesbury', ax=axes[1,2])
sns.lineplot(data=demog, x='LGA (UR)', y='Liverpool', ax=axes[2,0])
sns.lineplot(data=demog, x='LGA (UR)', y='Parramatta', ax=axes[2,1])
sns.lineplot(data=demog, x='LGA (UR)', y='Penrith', ax=axes[2,2])
sns.lineplot(data=demog, x='LGA (UR)', y='Wollondilly', ax=axes[3,0])
# Out:
# <div id='097c0445-2ef5-434b-bf2a-fbca815aab79'></div>
# <AxesSubplot:xlabel='LGA (UR)', ylabel='Wollondilly'>

# %%
# Out:
# ...
# ERROR: Could not install packages due to an EnvironmentError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\jono\\Anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'
# Consider using the `--user` option or check the permissions.
#   Using cached matplotlib-3.6.2-cp38-cp38-win_amd64.whl (7.2 MB)
# ...

# %%
income
# Out:
#                                LGA (UR)  Blacktown  Blue Mountains    Camden  \
# 0   INCP Total Personal Income (weekly)        NaN             NaN       NaN
# 1                              Negative     2730.0           296.0     615.0
# 2                                     0    35116.0          4954.0    7982.0
# 3                                   149     8118.0          2329.0    2448.0
# 4                                   299    13447.0          3033.0    3354.0
# 5                                   399    20786.0          4588.0    5190.0
# 6                                   499    19448.0          5187.0    4701.0
# 7                                   649    18826.0          5154.0    5592.0
# 8                                   799    19971.0          4764.0    5748.0
# 9                                   999    25768.0          4813.0    7503.0
# 10                                 1249    30755.0          5553.0    9461.0
# ...

# %%
income2 = income.iloc[1:-3,1:-2]/income.iloc[-1,1:-2]*100
income2 = income2.astype('float')
income2.index = income['LGA (UR)'].iloc[1:-3]

# %%
plt.figure(figsize = (20,12))
sns.lineplot(data=income2)
plt.show()
# Out:
# <div id='b4df41ea-2c59-4317-8317-d68d195f9314'></div>

# %%
import matplotlib.pyplot as plt
import numpy as np; np.random.seed(1)

x = np.random.rand(15)
y = np.random.rand(15)
names = np.array(list("ABCDEFGHIJKLMNO"))
c = np.random.randint(1,5,size=15)

norm = plt.Normalize(1,4)
cmap = plt.cm.RdYlGn

fig,ax = plt.subplots()
sc = plt.scatter(x,y,c=c, s=100, cmap=cmap, norm=norm)

annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->"))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    annot.xy = pos
    text = "{}, {}".format(" ".join(list(map(str,ind["ind"]))), 
                           " ".join([names[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor(cmap(norm(c[ind["ind"][0]])))
    annot.get_bbox_patch().set_alpha(0.4)


def hover(event):
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()

fig.canvas.mpl_connect("motion_notify_event", hover)

plt.show()
# Out:
# <div id='073148df-e00e-425f-b7fc-9caad5450c19'></div>

# %%
pip install ipympl
# Out:
# ...
#   Using cached ipympl-0.9.2-py2.py3-none-any.whl (510 kB)
# ...
#   Using cached matplotlib-3.6.2-cp38-cp38-win_amd64.whl (7.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an EnvironmentError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\jono\\Anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'
# Consider using the `--user` option or check the permissions.

# %%
# %matplotlib widget
